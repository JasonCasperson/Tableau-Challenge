# %%
import pandas as pd

july_data = pd.read_csv('202307-citibike-tripdata.csv')
august_data = pd.read_csv('202308-citibike-tripdata.csv')
sept_data = pd.read_csv('202309-citibike-tripdata.csv')

final_frame = pd.concat([july_data,august_data,sept_data])

final_frame.to_csv('Bike_Trip_FinalData.csv')
# Out:
# /var/folders/7k/6nnx_jrs1kj7qg39rwhwdr180000gn/T/ipykernel_34264/2514710824.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   july_data = pd.read_csv('202307-citibike-tripdata.csv')
# /var/folders/7k/6nnx_jrs1kj7qg39rwhwdr180000gn/T/ipykernel_34264/2514710824.py:4: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   august_data = pd.read_csv('202308-citibike-tripdata.csv')
# /var/folders/7k/6nnx_jrs1kj7qg39rwhwdr180000gn/T/ipykernel_34264/2514710824.py:5: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   sept_data = pd.read_csv('202309-citibike-tripdata.csv')
